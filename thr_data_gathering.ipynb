# %%
hollywoodreporter_url = "https://www.hollywoodreporter.com/topic/movie-reviews"
review_url = "https://www.hollywoodreporter.com/review/"
#javascript class = article__deck
#http://www.omdbapi.com/ -- public api for IMDB

# %%
import pandas
import requests
from pandas import read_html
from pandas import DataFrame

# %%
#auth = (tokens.auth_login, tokens.auth_pswd)
response = requests.get(review_url)
print(response.text)
#list_of_data_frames = read_html(response.text)
#return list_of_data_frames[0]
